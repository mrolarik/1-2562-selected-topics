# %% [markdown]
# # วิธีการ comment ของ python
# ## วิธีการ comment ของ python

# %%
# python

'''
multi-line comment
'''
# Out:
# '\nmulti-line comment\n'

# %% [markdown]
# # Error ที่เกิดจากการกำหนด syntax ผิดพลาด

# %%
# print python2
print"hello"
# Out:
#   File "<ipython-input-4-26542d529988>", line 1
#     print"hello"
#                ^
# SyntaxError: invalid syntax

# %%
# print python3
print('Hello World')
print("Hello World")
# Out:
# Hello World
# Hello World

# %%
# built-in function
# print()

# %%
import keyword

a = keyword.kwlist
print(type(a))
# Out:
# <class 'list'>

# %%
len(a)
# Out:
# 33

# %%
a[0]    # variable[index]
# Out:
# 'False'

# %%
a[len(a)]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-836f840eaf9f> in <module>()
# ----> 1 a[len(a)]
#
# IndexError: list index out of range

# %%
a[1:5]
# Out:
# ['None', 'True', 'and', 'as']

# %%
a[20:34]
# Out:
# ['in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
type(a[0])
# Out:
# str

# %%
b = a[0]
print(type(b))
# Out:
# <class 'str'>

# %%
print(b)
# Out:
# False

# %%
len(b)
# Out:
# 5

# %%
print(b[0])
print(b[1])
# Out:
# F
# a

# %%
print(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-1dd5973cae19> in <module>()
# ----> 1 print(c)
#
# NameError: name 'c' is not defined

# %%
print('c')
# Out:
# c

# %%
c = 10+20

# %%
print(c)
print(type(c))
# Out:
# 30
# <class 'int'>

# %%
print(type(['a','b','c','d']))
# Out:
# <class 'list'>

# %%
d = ['a','b','c','d']
print(type(d))
print(d)
# Out:
# <class 'list'>
# ['a', 'b', 'c', 'd']

# %%
e = 'False'
print(type(e))
print(e)
# Out:
# <class 'str'>
# False

# %%
for i in [0,1,2]:
  print(i)
  print('ds')
# Out:
# 0
# ds
# 1
# ds
# 2
# ds
